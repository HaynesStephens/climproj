# %%
# %load column_code_with_slab.py
# %matplotlib notebook
from sympl import (
    DataArray, PlotFunctionMonitor,
    AdamsBashforth, get_constant
)
import numpy as np
from datetime import timedelta
import matplotlib.pyplot as plt

from climt import (
    EmanuelConvection, RRTMGShortwave, RRTMGLongwave, SlabSurface,
    DryConvectiveAdjustment, SimplePhysics, get_default_state
)

Cpd = get_constant('heat_capacity_of_dry_air_at_constant_pressure', 'J/kg/degK')
Cvap = get_constant('heat_capacity_of_vapor_phase', 'J/kg/K')
g = get_constant('gravitational_acceleration', 'm/s^2')
Lv = get_constant('latent_heat_of_condensation', 'J/kg')

def heat_capacity(q):

    return Cpd*(1-q) + Cvap*q


def calc_moist_enthalpy(state):
    
    dp = (state['air_pressure_on_interface_levels'][:-1] - state['air_pressure_on_interface_levels'][1:]).rename(
        dict(interface_levels='mid_levels'))
    
    C_tot = heat_capacity(state['specific_humidity'])
    
    return ((C_tot*state['air_temperature'] + Lv*state['specific_humidity'])*dp/g).sum().values

def plot_function(fig, state):
    ax = fig.add_subplot(1, 2, 1)
    ax.plot(
        state['air_temperature'].values.flatten(),
        state['air_pressure'].to_units('mbar').values.flatten(), '-o')
    ax.set_title('Air temperature')
    ax.axes.invert_yaxis()
    ax.set_xlabel('K')
    ax.grid()

    ax = fig.add_subplot(1, 2, 2)
    net_flux = (state['upwelling_longwave_flux_in_air'] +
                state['upwelling_shortwave_flux_in_air']-
                state['downwelling_longwave_flux_in_air'] -
                state['downwelling_shortwave_flux_in_air'])
    #ax.plot(
    #    (state['downwelling_longwave_flux_in_air'] - state['upwelling_longwave_flux_in_air']).values.flatten(),
    #    state['air_pressure_on_interface_levels'].to_units('mbar').values.flatten(), '-o', label='NetLW')
    #ax.plot(
    #    (state['downwelling_shortwave_flux_in_air'] - state['upwelling_shortwave_flux_in_air']).values.flatten(),
    #    state['air_pressure_on_interface_levels'].to_units('mbar').values.flatten(), '-o', label='NetSW')
    
    ax.plot(net_flux.values.flatten(),
            state['air_pressure_on_interface_levels'].to_units('mbar').values.flatten(), '-o', label='Net Flux')

    ax.legend()
    ax.set_title('Net Flux')
    ax.axes.invert_yaxis()
    ax.set_xlabel('W/m^2')
    ax.grid()
    plt.tight_layout()


monitor = PlotFunctionMonitor(plot_function)

timestep = timedelta(minutes=10)

radiation_sw = RRTMGShortwave()
radiation_lw = RRTMGLongwave()
slab = SlabSurface()
simple_physics = SimplePhysics()
dry_convection = DryConvectiveAdjustment()
moist_convection = EmanuelConvection()

state = get_default_state(
    [simple_physics, dry_convection, moist_convection,
     radiation_lw, radiation_sw, slab]
)

state['surface_temperature'].values[:] = 268.

state['air_temperature'].values[:] = 260
state['surface_albedo_for_direct_shortwave'].values[:] = 0.4
state['surface_albedo_for_direct_near_infrared'].values[:] = 0.4
state['surface_albedo_for_diffuse_shortwave'].values[:] = 0.4

state['zenith_angle'].values[:] = np.pi/2.45

state['ocean_mixed_layer_thickness'].values[:] = .01
state['area_type'].values[:] = 'sea'

equilibrium_value = DataArray(
    np.ones(len(state['air_pressure']))*10.,
    dims=('mid_levels'),
    attrs={'units': 'm s^-1'})

tau = DataArray(
    np.array(2.), dims=[], attrs={'units': 'hour'})

time_stepper = AdamsBashforth([radiation_lw, radiation_sw, slab, moist_convection])
net_flux = 0

old_enthalpy = calc_moist_enthalpy(state)

for i in range(100000):

    diagnostics, new_state = simple_physics(state, timestep)
    state.update(diagnostics)
    state.update(new_state)
    
    diagnostics, state = time_stepper(state, timestep)
    state.update(diagnostics)
        
    diagnostics, new_state = dry_convection(state, timestep)
    state.update(diagnostics)
    state.update(new_state)
    
    surf_flux_to_col = -(state['downwelling_shortwave_flux_in_air'][0] +
            state['downwelling_longwave_flux_in_air'][0] -
            state['upwelling_shortwave_flux_in_air'][0] -
            state['upwelling_longwave_flux_in_air'][0] -
            state['surface_upward_sensible_heat_flux'] -
            state['surface_upward_latent_heat_flux']).values
        
    toa_flux_to_col = (state['downwelling_shortwave_flux_in_air'][-1] -
                       state['upwelling_shortwave_flux_in_air'][-1] -
                        state['upwelling_longwave_flux_in_air'][-1]).values
    
    
    #print('TOA flux:', toa_flux_to_col)
    #print('Surf flux:', surf_flux_to_col)
        
    total_heat_gain = surf_flux_to_col + toa_flux_to_col
    current_enthalpy = calc_moist_enthalpy(state)
    enthalpy_gain = current_enthalpy - old_enthalpy
    old_enthalpy = current_enthalpy
    
    if i % 100 == 0:
        monitor.store(state)

        print(i)
        print('Forcing and Column integral: ', total_heat_gain, enthalpy_gain/timestep.total_seconds())
        print('TOA flux:', toa_flux_to_col)
        print('Surf flux:', surf_flux_to_col)
    
        
      
    state.update(new_state)
    state['eastward_wind'].values[:] = 3.
# Out:
# <img src="data:image/png;base64,..." width="640">
# /Users/haynesstephens1/anaconda3/lib/python3.6/site-packages/sympl/_core/tendencystepper.py:148: UserWarning: Using an ImplicitTendencyComponent in sympl TendencyStepper objects may lead to scientifically invalid results. Make sure the component follows the same numerical assumptions as the TendencyStepper used.
#   'Using an ImplicitTendencyComponent in sympl TendencyStepper objects may '
# 0
# Forcing and Column integral:  [[-38.93942938]] -38.939429377714795
# TOA flux: [[-48.55442273]]
# Surf flux: [[9.61499335]]
# 100
# Forcing and Column integral:  [[-36.49253456]] -34.67289605696996
# TOA flux: [[-33.49352205]]
# Surf flux: [[-2.99901252]]
# 200
# Forcing and Column integral:  [[-32.14733309]] -29.872884232997894
# TOA flux: [[-30.26922249]]
# Surf flux: [[-1.87811059]]
# 300
# Forcing and Column integral:  [[-27.60712136]] -24.996542908350627
# TOA flux: [[-26.62178755]]
# Surf flux: [[-0.98533381]]
# 400
# Forcing and Column integral:  [[-25.83347327]] -24.18075379371643
# TOA flux: [[-25.09477741]]
# Surf flux: [[-0.73869586]]
# 500
# Forcing and Column integral:  [[-23.68712]] -21.29635603904724
# TOA flux: [[-22.96052137]]
# Surf flux: [[-0.72659863]]
# 600
# Forcing and Column integral:  [[-24.86399257]] -24.12561818599701
# TOA flux: [[-24.39900814]]
# Surf flux: [[-0.46498442]]
# 700
# Forcing and Column integral:  [[-22.50421888]] -19.763559877872467
# TOA flux: [[-22.03946805]]
# Surf flux: [[-0.46475082]]
# 800
# Forcing and Column integral:  [[-24.40495401]] -23.984118616580965
# TOA flux: [[-24.03416613]]
# Surf flux: [[-0.37078788]]
# 900
# Forcing and Column integral:  [[-23.09414551]] -21.89533332745234
# TOA flux: [[-22.7270877]]
# Surf flux: [[-0.36705781]]
# 1000
# Forcing and Column integral:  [[-21.19328576]] -21.981676840782164
# TOA flux: [[-20.84243598]]
# Surf flux: [[-0.35084978]]
# 1100
# Forcing and Column integral:  [[-23.51143795]] -23.422948456605276
# TOA flux: [[-23.22280733]]
# Surf flux: [[-0.28863062]]
# 1200
# Forcing and Column integral:  [[-22.76607312]] -22.276628827253976
# TOA flux: [[-22.53345917]]
# Surf flux: [[-0.23261395]]
# 1300
# Forcing and Column integral:  [[-21.32258842]] -20.13770622173945
# TOA flux: [[-21.05721188]]
# Surf flux: [[-0.26537654]]
# 1400
# Forcing and Column integral:  [[-18.95169256]] -16.94749856233597
# TOA flux: [[-18.69596712]]
# Surf flux: [[-0.25572544]]
# 1500
# Forcing and Column integral:  [[-22.06541402]] -22.45918088992437
# TOA flux: [[-21.82761027]]
# Surf flux: [[-0.23780375]]
# 1600
# Forcing and Column integral:  [[-22.18773478]] -22.30906909783681
# TOA flux: [[-22.03616123]]
# Surf flux: [[-0.15157355]]
# 1700
# Forcing and Column integral:  [[-21.46890783]] -20.96237091064453
# TOA flux: [[-21.2967714]]
# Surf flux: [[-0.17213643]]
# 1800
# Forcing and Column integral:  [[-20.30005284]] -19.420618813037873
# TOA flux: [[-20.12206214]]
# Surf flux: [[-0.17799071]]
# 1900
# Forcing and Column integral:  [[-18.72756782]] -17.471528212229412
# TOA flux: [[-18.54263908]]
# Surf flux: [[-0.18492874]]
# 2000
# Forcing and Column integral:  [[-16.77736932]] -15.040242869853973
# TOA flux: [[-16.58774047]]
# Surf flux: [[-0.18962885]]
# 2100
# Forcing and Column integral:  [[-20.15865084]] -20.966733787854512
# TOA flux: [[-19.98854803]]
# Surf flux: [[-0.17010281]]
# 2200
# Forcing and Column integral:  [[-20.87272646]] -21.173430942694345
# TOA flux: [[-20.77213204]]
# Surf flux: [[-0.10059443]]
# 2300
# Forcing and Column integral:  [[-20.51694991]] -20.40095034122467
# TOA flux: [[-20.40608273]]
# Surf flux: [[-0.11086718]]
# 2400
# Forcing and Column integral:  [[-19.85365091]] -19.427472616036734
# TOA flux: [[-19.74409337]]
# Surf flux: [[-0.10955754]]
# 2500
# Forcing and Column integral:  [[-18.99975345]] -18.409965052604676
# TOA flux: [[-18.88525634]]
# Surf flux: [[-0.11449711]]
# 2600
# Forcing and Column integral:  [[-18.00197067]] -17.285624465147656
# TOA flux: [[-17.88726758]]
# Surf flux: [[-0.11470309]]
# 2700
# Forcing and Column integral:  [[-16.75180765]] -15.868057380517325
# TOA flux: [[-16.63199724]]
# Surf flux: [[-0.11981041]]
# 2800
# Forcing and Column integral:  [[-15.25677867]] -14.060886171658835
# TOA flux: [[-15.12425199]]
# Surf flux: [[-0.13252668]]
# 2900
# Forcing and Column integral:  [[-14.99395242]] -16.919700640837352
# TOA flux: [[-14.93144847]]
# Surf flux: [[-0.06250395]]
# 3000
# Forcing and Column integral:  [[-16.76289639]] -15.688758074442546
# TOA flux: [[-16.61275832]]
# Surf flux: [[-0.15013807]]
# 3100
# Forcing and Column integral:  [[-16.40992924]] -19.9916681265831
# TOA flux: [[-16.22917369]]
# Surf flux: [[-0.18075555]]
# 3200
# Forcing and Column integral:  [[-15.61700407]] -12.114078772068023
# TOA flux: [[-15.55031372]]
# Surf flux: [[-0.06669035]]
# 3300
# Forcing and Column integral:  [[-15.01094443]] -18.105077176888784
# TOA flux: [[-14.91231089]]
# Surf flux: [[-0.09863354]]
# 3400
# Forcing and Column integral:  [[-14.13808685]] -10.856172238190968
# TOA flux: [[-14.10369062]]
# Surf flux: [[-0.03439623]]
# 3500
# Forcing and Column integral:  [[-13.56105868]] -16.179818115234376
# TOA flux: [[-13.39874823]]
# Surf flux: [[-0.16231046]]
# 3600
# Forcing and Column integral:  [[-12.95190741]] -14.746203325589498
# TOA flux: [[-12.79365366]]
# Surf flux: [[-0.15825375]]
# 3700
# Forcing and Column integral:  [[-12.30436321]] -11.978844943841299
# TOA flux: [[-12.19961235]]
# Surf flux: [[-0.10475086]]
# 3800
# Forcing and Column integral:  [[-11.34448212]] -10.783330934047699
# TOA flux: [[-11.24720848]]
# Surf flux: [[-0.09727364]]
# 3900
# Forcing and Column integral:  [[-14.16203323]] -14.549829108715057
# TOA flux: [[-14.05754966]]
# Surf flux: [[-0.10448357]]
# 4000
# Forcing and Column integral:  [[-15.68533885]] -14.427804849942525
# TOA flux: [[-15.55947465]]
# Surf flux: [[-0.1258642]]
# 4100
# Forcing and Column integral:  [[-15.7141286]] -14.943678046067555
# TOA flux: [[-15.66935105]]
# Surf flux: [[-0.04477755]]
# 4200
# Forcing and Column integral:  [[-15.51148026]] -15.707628568808238
# TOA flux: [[-15.45051432]]
# Surf flux: [[-0.06096595]]
# 4300
# Forcing and Column integral:  [[-15.12457299]] -21.593950413862864
# TOA flux: [[-14.89991596]]
# Surf flux: [[-0.22465702]]
# 4400
# Forcing and Column integral:  [[-14.93257122]] -14.991247432231903
# TOA flux: [[-14.87637077]]
# Surf flux: [[-0.05620044]]
# 4500
# Forcing and Column integral:  [[-14.38674729]] -20.472796416282655
# TOA flux: [[-14.15871186]]
# Surf flux: [[-0.22803543]]
# 4600
# Forcing and Column integral:  [[-13.96016731]] -19.65378413597743
# TOA flux: [[-13.75917033]]
# Surf flux: [[-0.20099698]]
# 4700
# Forcing and Column integral:  [[-13.70623588]] -19.257998436292013
# TOA flux: [[-13.47013126]]
# Surf flux: [[-0.23610462]]
# 4800
# Forcing and Column integral:  [[-13.45508124]] -17.59318673769633
# TOA flux: [[-13.29958452]]
# Surf flux: [[-0.15549672]]
# 4900
# Forcing and Column integral:  [[-14.07690164]] -14.319925847848257
# TOA flux: [[-14.02029419]]
# Surf flux: [[-0.05660745]]
# 5000
# Forcing and Column integral:  [[-14.25357202]] -14.51930467526118
# TOA flux: [[-14.21782949]]
# Surf flux: [[-0.03574253]]
# 5100
# Forcing and Column integral:  [[-13.48265151]] -17.88513790766398
# TOA flux: [[-13.33507548]]
# Surf flux: [[-0.14757603]]
# 5200
# Forcing and Column integral:  [[-13.02944031]] -17.06504032055537
# TOA flux: [[-12.80250477]]
# Surf flux: [[-0.22693554]]
# 5300
# Forcing and Column integral:  [[-12.61805644]] -7.794380339781443
# TOA flux: [[-12.65986405]]
# Surf flux: [[0.04180761]]
# 5400
# Forcing and Column integral:  [[-12.52499005]] -12.870067713260651
# TOA flux: [[-12.50860565]]
# Surf flux: [[-0.01638439]]
# 5500
# Forcing and Column integral:  [[-12.3421142]] -7.293042891820272
# TOA flux: [[-12.38333394]]
# Surf flux: [[0.04121974]]
# 5600
# Forcing and Column integral:  [[-13.01692917]] -5.428371017773946
# TOA flux: [[-13.21835826]]
# Surf flux: [[0.20142909]]
# 5700
# Forcing and Column integral:  [[-13.64375331]] -6.300143872896831
# TOA flux: [[-13.78335256]]
# Surf flux: [[0.13959925]]
# 5800
# Forcing and Column integral:  [[-14.80936101]] -8.862657103538513
# TOA flux: [[-14.83078255]]
# Surf flux: [[0.02142154]]
# 5900
# Forcing and Column integral:  [[-13.64101557]] -11.097082027594249
# TOA flux: [[-13.70552147]]
# Surf flux: [[0.06450589]]
# 6000
# Forcing and Column integral:  [[-13.12412858]] -5.5498169422149655
# TOA flux: [[-13.33489683]]
# Surf flux: [[0.21076825]]
# 6100
# Forcing and Column integral:  [[-13.14510352]] -17.859332007567087
# TOA flux: [[-13.01046639]]
# Surf flux: [[-0.13463713]]
# 6200
# Forcing and Column integral:  [[-12.85271899]] -12.555539831320445
# TOA flux: [[-12.93055419]]
# Surf flux: [[0.0778352]]
# 6300
# Forcing and Column integral:  [[-12.60711537]] -4.99314129114151
# TOA flux: [[-12.81411428]]
# Surf flux: [[0.20699892]]
# 6400
# Forcing and Column integral:  [[-12.54952213]] -12.711012493769328
# TOA flux: [[-12.56530117]]
# Surf flux: [[0.01577905]]
# 6500
# Forcing and Column integral:  [[-12.36506387]] -15.236023082733155
# TOA flux: [[-12.22244086]]
# Surf flux: [[-0.14262301]]
# 6600
# Forcing and Column integral:  [[-12.14186324]] -17.123000429471332
# TOA flux: [[-11.96314564]]
# Surf flux: [[-0.1787176]]
# 6700
# Forcing and Column integral:  [[-11.72977989]] -7.598388045628866
# TOA flux: [[-11.8614684]]
# Surf flux: [[0.13168851]]
# 6800
# Forcing and Column integral:  [[-11.45587844]] -4.066322045326233
# TOA flux: [[-11.62587267]]
# Surf flux: [[0.16999423]]
# 6900
# Forcing and Column integral:  [[-11.41122986]] -15.984239252408345
# TOA flux: [[-11.27671195]]
# Surf flux: [[-0.13451792]]
# 7000
# Forcing and Column integral:  [[-11.3048656]] -17.83160120566686
# TOA flux: [[-11.06787321]]
# Surf flux: [[-0.2369924]]
# 7100
# Forcing and Column integral:  [[-11.18585706]] -17.711938153107962
# TOA flux: [[-10.90306698]]
# Surf flux: [[-0.28279008]]
# 7200
# Forcing and Column integral:  [[-11.12124459]] -17.55042373339335
# TOA flux: [[-10.83599891]]
# Surf flux: [[-0.28524568]]
# 7300
# Forcing and Column integral:  [[-11.16468465]] -17.394778776963552
# TOA flux: [[-10.89345833]]
# Surf flux: [[-0.27122633]]
# 7400
# Forcing and Column integral:  [[-10.81069032]] -7.982971041202545
# TOA flux: [[-10.85293032]]
# Surf flux: [[0.04224001]]
# 7500
# Forcing and Column integral:  [[-10.48432174]] -11.553036863803863
# TOA flux: [[-10.55320427]]
# Surf flux: [[0.06888253]]
# 7600
# Forcing and Column integral:  [[-10.5238685]] -16.26481362581253
# TOA flux: [[-10.30087725]]
# Surf flux: [[-0.22299124]]
# 7700
# Forcing and Column integral:  [[-10.43233875]] -16.234122641881306
# TOA flux: [[-10.16197945]]
# Surf flux: [[-0.27035931]]
# 7800
# Forcing and Column integral:  [[-10.19431959]] -7.858691398302714
# TOA flux: [[-10.2232128]]
# Surf flux: [[0.02889322]]
# 7900
# Forcing and Column integral:  [[-10.15780553]] -4.412367802460988
# TOA flux: [[-10.22822214]]
# Surf flux: [[0.07041661]]
# 8000
# Forcing and Column integral:  [[-10.35674836]] -15.401083714167276
# TOA flux: [[-10.13685941]]
# Surf flux: [[-0.21988895]]
# 8100
# Forcing and Column integral:  [[-10.32142985]] -4.260064996878306
# TOA flux: [[-10.40970827]]
# Surf flux: [[0.08827842]]
# 8200
# Forcing and Column integral:  [[-10.12927152]] -6.325151657263438
# TOA flux: [[-10.26260842]]
# Surf flux: [[0.1333369]]
# 8300
# Forcing and Column integral:  [[-10.69440196]] -5.84582155307134
# TOA flux: [[-10.89301089]]
# Surf flux: [[0.19860893]]
# 8400
# Forcing and Column integral:  [[-11.56208755]] -8.725475203990936
# TOA flux: [[-11.70472015]]
# Surf flux: [[0.1426326]]
# 8500
# Forcing and Column integral:  [[-11.71836196]] -6.7621268431345625
# TOA flux: [[-11.89574084]]
# Surf flux: [[0.17737888]]
# 8600
# Forcing and Column integral:  [[-11.62615077]] -8.263647103309632
# TOA flux: [[-11.73305218]]
# Surf flux: [[0.10690141]]
# 8700
# Forcing and Column integral:  [[-10.49620053]] -3.332441703478495
# TOA flux: [[-10.75945973]]
# Surf flux: [[0.2632592]]
# 8800
# Forcing and Column integral:  [[-10.65988953]] -10.78238865296046
# TOA flux: [[-10.64621524]]
# Surf flux: [[-0.01367429]]
# 8900
# Forcing and Column integral:  [[-10.32181428]] -12.18223763068517
# TOA flux: [[-10.22702004]]
# Surf flux: [[-0.09479425]]
# 9000
# Forcing and Column integral:  [[-10.20776958]] -10.478453971544901
# TOA flux: [[-10.19096456]]
# Surf flux: [[-0.01680501]]
# 9100
# Forcing and Column integral:  [[-10.46980905]] -6.916501581668854
# TOA flux: [[-10.5511463]]
# Surf flux: [[0.08133724]]
# 9200
# Forcing and Column integral:  [[-10.22491974]] -10.466009412606557
# TOA flux: [[-10.20935644]]
# Surf flux: [[-0.01556331]]
# 9300
# Forcing and Column integral:  [[-10.43393479]] -18.815320262908937
# TOA flux: [[-10.18519774]]
# Surf flux: [[-0.24873705]]
# 9400
# Forcing and Column integral:  [[-10.27309579]] -18.567642657756807
# TOA flux: [[-10.01508283]]
# Surf flux: [[-0.25801296]]
# 9500
# Forcing and Column integral:  [[-9.85657444]] -1.4086736194292704
# TOA flux: [[-10.07047293]]
# Surf flux: [[0.21389849]]
# 9600
# Forcing and Column integral:  [[-10.142456]] -6.601454852422078
# TOA flux: [[-10.2423259]]
# Surf flux: [[0.0998699]]
# 9700
# Forcing and Column integral:  [[-10.00510219]] -1.6459618131319682
# TOA flux: [[-10.21407022]]
# Surf flux: [[0.20896804]]
# 9800
# Forcing and Column integral:  [[-9.84576533]] -5.5455831591288245
# TOA flux: [[-10.01285513]]
# Surf flux: [[0.1670898]]
# 9900
# Forcing and Column integral:  [[-10.08965078]] -6.518368085225423
# TOA flux: [[-10.17561214]]
# Surf flux: [[0.08596136]]
# 10000
# Forcing and Column integral:  [[-9.95736389]] -6.354553994337718
# TOA flux: [[-10.08460235]]
# Surf flux: [[0.12723847]]
# 10100
# Forcing and Column integral:  [[-9.7207395]] -12.014089945952097
# TOA flux: [[-9.66891063]]
# Surf flux: [[-0.05182887]]
# 10200
# Forcing and Column integral:  [[-10.02417424]] -13.663072729110718
# TOA flux: [[-9.89464531]]
# Surf flux: [[-0.12952893]]
# 10300
# Forcing and Column integral:  [[-10.17030053]] -13.775683716932933
# TOA flux: [[-10.0483322]]
# Surf flux: [[-0.12196833]]
# 10400
# Forcing and Column integral:  [[-10.18390043]] -12.16814543803533
# TOA flux: [[-10.16146009]]
# Surf flux: [[-0.02244034]]
# 10500
# Forcing and Column integral:  [[-10.11776062]] -12.0792307639122
# TOA flux: [[-10.1025962]]
# Surf flux: [[-0.01516443]]
# 10600
# Forcing and Column integral:  [[-9.83491829]] -13.657794717947642
# TOA flux: [[-9.70809331]]
# Surf flux: [[-0.12682498]]
# 10700
# Forcing and Column integral:  [[-9.82260478]] -14.213500247001647
# TOA flux: [[-9.65760858]]
# Surf flux: [[-0.16499619]]
# 10800
# Forcing and Column integral:  [[-9.79004532]] -12.042772114276886
# TOA flux: [[-9.77234311]]
# Surf flux: [[-0.01770221]]
# 10900
# Forcing and Column integral:  [[-9.95948632]] -15.549104758103688
# TOA flux: [[-9.77391806]]
# Surf flux: [[-0.18556827]]
# 11000
# Forcing and Column integral:  [[-9.89626398]] -14.826103672981262
# TOA flux: [[-9.78194836]]
# Surf flux: [[-0.11431562]]
# 11100
# Forcing and Column integral:  [[-9.9457749]] -17.43255355278651
# TOA flux: [[-9.65941344]]
# Surf flux: [[-0.28636145]]
# 11200
# Forcing and Column integral:  [[-9.70670667]] -11.511509767373402
# TOA flux: [[-9.68343225]]
# Surf flux: [[-0.02327442]]
# 11300
# Forcing and Column integral:  [[-9.83074809]] -17.25455356836319
# TOA flux: [[-9.54163213]]
# Surf flux: [[-0.28911596]]
# 11400
# Forcing and Column integral:  [[-9.5516202]] -11.635020101865132
# TOA flux: [[-9.53618247]]
# Surf flux: [[-0.01543773]]
# 11500
# Forcing and Column integral:  [[-9.57079329]] -13.121573861440023
# TOA flux: [[-9.46615981]]
# Surf flux: [[-0.10463347]]
# 11600
# Forcing and Column integral:  [[-9.47993185]] -11.9928604443868
# TOA flux: [[-9.41888872]]
# Surf flux: [[-0.06104313]]
# 11700
# Forcing and Column integral:  [[-9.49513444]] -14.5852618988355
# TOA flux: [[-9.30469475]]
# Surf flux: [[-0.19043969]]
# 11800
# Forcing and Column integral:  [[-9.45485146]] -16.516128753026326
# TOA flux: [[-9.17453809]]
# Surf flux: [[-0.28031337]]
# 11900
# Forcing and Column integral:  [[-9.2516289]] -11.721427489121755
# TOA flux: [[-9.19678295]]
# Surf flux: [[-0.05484594]]
# 12000
# Forcing and Column integral:  [[-9.20081395]] -11.27412904103597
# TOA flux: [[-9.18714357]]
# Surf flux: [[-0.01367038]]
# 12100
# Forcing and Column integral:  [[-9.12228788]] -11.140649236838023
# TOA flux: [[-9.08961295]]
# Surf flux: [[-0.03267493]]
# 12200
# Forcing and Column integral:  [[-9.00496929]] -11.27849837144216
# TOA flux: [[-8.98167973]]
# Surf flux: [[-0.02328956]]
# 12300
# Forcing and Column integral:  [[-9.00929932]] -13.273015720844269
# TOA flux: [[-8.90441906]]
# Surf flux: [[-0.10488027]]
# 12400
# Forcing and Column integral:  [[-9.03139396]] -13.719861070315043
# TOA flux: [[-8.85270352]]
# Surf flux: [[-0.17869044]]
# 12500
# Forcing and Column integral:  [[-8.84627465]] -11.809106681346893
# TOA flux: [[-8.82417873]]
# Surf flux: [[-0.02209592]]
# 12600
# Forcing and Column integral:  [[-9.00705859]] -15.442553459008534
# TOA flux: [[-8.76228193]]
# Surf flux: [[-0.24477667]]
# 12700
# Forcing and Column integral:  [[-8.77636622]] -11.697289757728576
# TOA flux: [[-8.71550634]]
# Surf flux: [[-0.06085989]]
# 12800
# Forcing and Column integral:  [[-8.67623655]] -13.146387890974681
# TOA flux: [[-8.50184952]]
# Surf flux: [[-0.17438703]]
# 12900
# Forcing and Column integral:  [[-8.6714932]] -12.881775114536286
# TOA flux: [[-8.56274822]]
# Surf flux: [[-0.10874498]]
# 13000
# Forcing and Column integral:  [[-8.49541916]] -6.618670552571615
# TOA flux: [[-8.62942574]]
# Surf flux: [[0.13400658]]
# 13100
# Forcing and Column integral:  [[-8.63223007]] -4.637882022857666
# TOA flux: [[-8.75719343]]
# Surf flux: [[0.12496337]]
# 13200
# Forcing and Column integral:  [[-8.71581056]] -4.8583925914764405
# TOA flux: [[-8.83105752]]
# Surf flux: [[0.11524696]]
# 13300
# Forcing and Column integral:  [[-8.934478]] -15.04954645315806
# TOA flux: [[-8.7028122]]
# Surf flux: [[-0.23166581]]
# 13400
# Forcing and Column integral:  [[-8.77842208]] -11.370025316079458
# TOA flux: [[-8.75218801]]
# Surf flux: [[-0.02623407]]
# 13500
# Forcing and Column integral:  [[-8.73922748]] -4.959087325731914
# TOA flux: [[-8.86095625]]
# Surf flux: [[0.12172877]]
# 13600
# Forcing and Column integral:  [[-8.79486546]] -9.003673992951711
# TOA flux: [[-8.925905]]
# Surf flux: [[0.13103954]]
# 13700
# Forcing and Column integral:  [[-8.94237105]] -12.854301012357077
# TOA flux: [[-8.86651712]]
# Surf flux: [[-0.07585393]]
# 13800
# Forcing and Column integral:  [[-9.03510509]] -9.981095570723216
# TOA flux: [[-9.11626424]]
# Surf flux: [[0.08115915]]
# 13900
# Forcing and Column integral:  [[-9.28887287]] -14.330982171694437
# TOA flux: [[-9.06858609]]
# Surf flux: [[-0.22028678]]
# 14000
# Forcing and Column integral:  [[-8.86613996]] -3.426829152901967
# TOA flux: [[-8.98391833]]
# Surf flux: [[0.11777837]]
# 14100
# Forcing and Column integral:  [[-8.38641367]] -4.045906211535136
# TOA flux: [[-8.46719683]]
# Surf flux: [[0.08078316]]
# 14200
# Forcing and Column integral:  [[-7.91904356]] -4.350155221621195
# TOA flux: [[-8.04669369]]
# Surf flux: [[0.12765014]]
# 14300
# Forcing and Column integral:  [[-7.7714409]] -0.6579162796338399
# TOA flux: [[-7.93257275]]
# Surf flux: [[0.16113184]]
# 14400
# Forcing and Column integral:  [[-8.29589223]] -17.13541061639786
# TOA flux: [[-8.00805693]]
# Surf flux: [[-0.2878353]]
# 14500
# Forcing and Column integral:  [[-8.60396016]] -13.13701298713684
# TOA flux: [[-8.43170317]]
# Surf flux: [[-0.17225699]]
# 14600
# Forcing and Column integral:  [[-8.42094786]] -8.019080315430958
# TOA flux: [[-8.59677217]]
# Surf flux: [[0.1758243]]
# 14700
# Forcing and Column integral:  [[-8.37864408]] -10.37577755053838
# TOA flux: [[-8.33805031]]
# Surf flux: [[-0.04059377]]
# 14800
# Forcing and Column integral:  [[-8.15728648]] -7.455986204942067
# TOA flux: [[-8.23255201]]
# Surf flux: [[0.07526552]]
# 14900
# Forcing and Column integral:  [[-8.07980417]] -10.094111990133921
# TOA flux: [[-8.08151849]]
# Surf flux: [[0.00171432]]
# 15000
# Forcing and Column integral:  [[-8.18305771]] -9.7027153023084
# TOA flux: [[-8.15098383]]
# Surf flux: [[-0.03207388]]
# 15100
# Forcing and Column integral:  [[-8.13385187]] -9.490599032243093
# TOA flux: [[-8.15102077]]
# Surf flux: [[0.01716891]]
# 15200
# Forcing and Column integral:  [[-8.07208263]] -9.584937397638956
# TOA flux: [[-8.06164554]]
# Surf flux: [[-0.01043709]]
# 15300
# Forcing and Column integral:  [[-8.03173261]] -4.525131189028422
# TOA flux: [[-8.13768464]]
# Surf flux: [[0.10595203]]
# 15400
# Forcing and Column integral:  [[-8.09759751]] -5.413326507409414
# TOA flux: [[-8.14778626]]
# Surf flux: [[0.05018875]]
# 15500
# Forcing and Column integral:  [[-7.99988202]] -7.325914402008056
# TOA flux: [[-8.06513777]]
# Surf flux: [[0.06525575]]
# 15600
# Forcing and Column integral:  [[-7.8741584]] -11.68063747326533
# TOA flux: [[-7.70755578]]
# Surf flux: [[-0.16660263]]
# 15700
# Forcing and Column integral:  [[-7.98272371]] -14.55620036760966
# TOA flux: [[-7.70668536]]
# Surf flux: [[-0.27603835]]
# 15800
# Forcing and Column integral:  [[-7.75150147]] -6.349558860460917
# TOA flux: [[-7.87754375]]
# Surf flux: [[0.12604228]]
# 15900
# Forcing and Column integral:  [[-7.74867594]] -6.8711292854944865
# TOA flux: [[-7.84490986]]
# Surf flux: [[0.09623393]]
# 16000
# Forcing and Column integral:  [[-7.85577755]] -7.197876719633738
# TOA flux: [[-7.89908347]]
# Surf flux: [[0.04330592]]
# 16100
# Forcing and Column integral:  [[-7.66250003]] -9.238486839930216
# TOA flux: [[-7.65972975]]
# Surf flux: [[-0.00277028]]
# 16200
# Forcing and Column integral:  [[-7.64024156]] -9.106446701685588
# TOA flux: [[-7.63344243]]
# Surf flux: [[-0.00679913]]
# 16300
# Forcing and Column integral:  [[-7.62565364]] -11.452036406199138
# TOA flux: [[-7.50778878]]
# Surf flux: [[-0.11786487]]
# 16400
# Forcing and Column integral:  [[-7.56829302]] -11.396250027020772
# TOA flux: [[-7.45356158]]
# Surf flux: [[-0.11473143]]
# 16500
# Forcing and Column integral:  [[-7.51089759]] -4.8752068471908565
# TOA flux: [[-7.55309206]]
# Surf flux: [[0.04219447]]
# 16600
# Forcing and Column integral:  [[-7.43918294]] -10.945584723949432
# TOA flux: [[-7.34779831]]
# Surf flux: [[-0.09138463]]
# 16700
# Forcing and Column integral:  [[-7.3956071]] -6.537367034753164
# TOA flux: [[-7.49238674]]
# Surf flux: [[0.09677964]]
# 16800
# Forcing and Column integral:  [[-7.37980236]] -9.408965911865234
# TOA flux: [[-7.3371529]]
# Surf flux: [[-0.04264946]]
# 16900
# Forcing and Column integral:  [[-7.3873264]] -6.6247245804468795
# TOA flux: [[-7.47747232]]
# Surf flux: [[0.09014592]]
# 17000
# Forcing and Column integral:  [[-7.44264671]] -15.106864726543426
# TOA flux: [[-7.21646576]]
# Surf flux: [[-0.22618095]]
# 17100
# Forcing and Column integral:  [[-7.21901732]] -5.894466994603475
# TOA flux: [[-7.34545845]]
# Surf flux: [[0.12644112]]
# 17200
# Forcing and Column integral:  [[-7.21791348]] -6.487626910209656
# TOA flux: [[-7.30883292]]
# Surf flux: [[0.09091944]]
# 17300
# Forcing and Column integral:  [[-7.14586708]] -5.837332059542338
# TOA flux: [[-7.27181447]]
# Surf flux: [[0.12594739]]
# 17400
# Forcing and Column integral:  [[-7.2379152]] -8.20642041126887
# TOA flux: [[-7.22870628]]
# Surf flux: [[-0.00920892]]
# 17500
# Forcing and Column integral:  [[-7.1572348]] -10.857565723260244
# TOA flux: [[-7.04739654]]
# Surf flux: [[-0.10983825]]
# 17600
# Forcing and Column integral:  [[-7.22405975]] -8.687638591130575
# TOA flux: [[-7.19944996]]
# Surf flux: [[-0.02460979]]
# 17700
# Forcing and Column integral:  [[-7.07600479]] -9.315237758159638
# TOA flux: [[-7.03567206]]
# Surf flux: [[-0.04033274]]
# 17800
# Forcing and Column integral:  [[-7.13633257]] -4.6037650068600975
# TOA flux: [[-7.18282484]]
# Surf flux: [[0.04649227]]
# 17900
# Forcing and Column integral:  [[-7.08211193]] -6.587167131900787
# TOA flux: [[-7.16070399]]
# Surf flux: [[0.07859206]]
# 18000
# Forcing and Column integral:  [[-7.03080589]] -6.345152369340261
# TOA flux: [[-7.10937851]]
# Surf flux: [[0.07857262]]
# 18100
# Forcing and Column integral:  [[-7.04558558]] -6.718551109631856
# TOA flux: [[-7.10100968]]
# Surf flux: [[0.0554241]]
# 18200
# Forcing and Column integral:  [[-6.90298553]] -6.2688503185907996
# TOA flux: [[-6.9937894]]
# Surf flux: [[0.09080387]]
# 18300
# Forcing and Column integral:  [[-6.82800409]] -3.469516049226125
# TOA flux: [[-6.92993963]]
# Surf flux: [[0.10193554]]
# 18400
# Forcing and Column integral:  [[-6.93458063]] -6.388310589790344
# TOA flux: [[-6.98317461]]
# Surf flux: [[0.04859398]]
# 18500
# Forcing and Column integral:  [[-6.86825632]] -8.27032078186671
# TOA flux: [[-6.84981602]]
# Surf flux: [[-0.0184403]]
# 18600
# Forcing and Column integral:  [[-6.80407893]] -7.66690816005071
# TOA flux: [[-6.84832734]]
# Surf flux: [[0.04424841]]
# 18700
# Forcing and Column integral:  [[-6.74569562]] -8.122998441060384
# TOA flux: [[-6.74698682]]
# Surf flux: [[0.0012912]]
# 18800
# Forcing and Column integral:  [[-6.71273054]] -8.114243063926697
# TOA flux: [[-6.71417821]]
# Surf flux: [[0.00144767]]
# 18900
# Forcing and Column integral:  [[-6.81331514]] -4.337600042025248
# TOA flux: [[-6.86202722]]
# Surf flux: [[0.04871208]]
# 19000
# Forcing and Column integral:  [[-6.56077596]] -4.598819952011109
# TOA flux: [[-6.76042898]]
# Surf flux: [[0.19965302]]
# 19100
# Forcing and Column integral:  [[-6.68677874]] -6.223841024239858
# TOA flux: [[-6.7507984]]
# Surf flux: [[0.06401966]]
# 19200
# Forcing and Column integral:  [[-6.59259858]] -7.982045597235362
# TOA flux: [[-6.58270777]]
# Surf flux: [[-0.00989081]]
# 19300
# Forcing and Column integral:  [[-6.60750367]] -6.181888786156972
# TOA flux: [[-6.68379115]]
# Surf flux: [[0.07628749]]
# 19400
# Forcing and Column integral:  [[-6.61169372]] -7.081351272265116
# TOA flux: [[-6.68148696]]
# Surf flux: [[0.06979324]]
# 19500
# Forcing and Column integral:  [[-6.54794183]] -2.6824356484413148
# TOA flux: [[-6.68795163]]
# Surf flux: [[0.1400098]]
# 19600
# Forcing and Column integral:  [[-6.51069143]] -8.731146601041159
# TOA flux: [[-6.44183419]]
# Surf flux: [[-0.06885724]]
# 19700
# Forcing and Column integral:  [[-6.48856371]] -5.751433559258779
# TOA flux: [[-6.57995618]]
# Surf flux: [[0.09139247]]
# 19800
# Forcing and Column integral:  [[-6.50740701]] -5.291198562781016
# TOA flux: [[-6.62790709]]
# Surf flux: [[0.12050008]]
# 19900
# Forcing and Column integral:  [[-6.42943845]] -6.1780771327018735
# TOA flux: [[-6.5433372]]
# Surf flux: [[0.11389875]]
# 20000
# Forcing and Column integral:  [[-6.44614126]] -5.6971366826693215
# TOA flux: [[-6.53505356]]
# Surf flux: [[0.08891231]]
# 20100
# Forcing and Column integral:  [[-6.31135036]] -2.431717913945516
# TOA flux: [[-6.45771527]]
# Surf flux: [[0.14636491]]
# 20200
# Forcing and Column integral:  [[-6.47817336]] -6.036065690517425
# TOA flux: [[-6.51123038]]
# Surf flux: [[0.03305702]]
# 20300
# Forcing and Column integral:  [[-6.36423515]] -7.5607350079218545
# TOA flux: [[-6.35718265]]
# Surf flux: [[-0.0070525]]
# 20400
# Forcing and Column integral:  [[-6.25551016]] -7.527964898745219
# TOA flux: [[-6.26692578]]
# Surf flux: [[0.01141562]]
# 20500
# Forcing and Column integral:  [[-6.30702363]] -12.476583869457246
# TOA flux: [[-6.05888763]]
# Surf flux: [[-0.24813599]]
# 20600
# Forcing and Column integral:  [[-6.28207446]] -5.085474181175232
# TOA flux: [[-6.4009233]]
# Surf flux: [[0.11884884]]
# 20700
# Forcing and Column integral:  [[-6.27652144]] -9.81316580692927
# TOA flux: [[-6.13005268]]
# Surf flux: [[-0.14646875]]
# 20800
# Forcing and Column integral:  [[-6.18551663]] -7.416412281990051
# TOA flux: [[-6.19492052]]
# Surf flux: [[0.00940389]]
# 20900
# Forcing and Column integral:  [[-6.26705432]] -3.8819063369433087
# TOA flux: [[-6.30749783]]
# Surf flux: [[0.0404435]]
# 21000
# Forcing and Column integral:  [[-6.08809236]] -9.598224707444508
# TOA flux: [[-5.94285574]]
# Surf flux: [[-0.14523662]]
# 21100
# Forcing and Column integral:  [[-6.1024351]] -7.397762591838837
# TOA flux: [[-6.09819833]]
# Surf flux: [[-0.00423677]]
# 21200
# Forcing and Column integral:  [[-6.09684819]] -0.22345135847727457
# TOA flux: [[-6.19185774]]
# Surf flux: [[0.09500955]]
# 21300
# Forcing and Column integral:  [[-6.04779641]] -5.805517914295197
# TOA flux: [[-6.16016309]]
# Surf flux: [[0.11236667]]
# 21400
# Forcing and Column integral:  [[-6.05688689]] -6.495599443912506
# TOA flux: [[-6.12512778]]
# Surf flux: [[0.06824089]]
# 21500
# Forcing and Column integral:  [[-6.08006559]] -11.470656255880991
# TOA flux: [[-5.88066033]]
# Surf flux: [[-0.19940526]]
# 21600
# Forcing and Column integral:  [[-6.06258023]] -11.47350326538086
# TOA flux: [[-5.85927857]]
# Surf flux: [[-0.20330166]]
# 21700
# Forcing and Column integral:  [[-6.01738185]] -9.213207481702169
# TOA flux: [[-5.94214218]]
# Surf flux: [[-0.07523967]]
# 21800
# Forcing and Column integral:  [[-5.92469092]] -4.790721619129181
# TOA flux: [[-6.021982]]
# Surf flux: [[0.09729108]]
# 21900
# Forcing and Column integral:  [[-5.9924588]] -3.6531364146868386
# TOA flux: [[-6.03686617]]
# Surf flux: [[0.04440737]]
# 22000
# Forcing and Column integral:  [[-5.94635012]] -6.797671140829722
# TOA flux: [[-5.94020531]]
# Surf flux: [[-0.00614481]]
# 22100
# Forcing and Column integral:  [[-5.85347737]] -3.5297264575958254
# TOA flux: [[-5.90297336]]
# Surf flux: [[0.04949599]]
# 22200
# Forcing and Column integral:  [[-5.86243268]] -7.5587973602612815
# TOA flux: [[-5.827546]]
# Surf flux: [[-0.03488668]]
# 22300
# Forcing and Column integral:  [[-5.8244767]] -3.5161783997217815
# TOA flux: [[-5.87346716]]
# Surf flux: [[0.04899046]]
# 22400
# Forcing and Column integral:  [[-5.69296381]] -1.9400624736150105
# TOA flux: [[-5.83014075]]
# Surf flux: [[0.13717694]]
# 22500
# Forcing and Column integral:  [[-5.77655004]] -6.476749197642008
# TOA flux: [[-5.80669352]]
# Surf flux: [[0.03014347]]
# 22600
# Forcing and Column integral:  [[-5.7444032]] -7.399678084850311
# TOA flux: [[-5.70700002]]
# Surf flux: [[-0.03740318]]
# 22700
# Forcing and Column integral:  [[-5.71784452]] -8.859934088389078
# TOA flux: [[-5.64083353]]
# Surf flux: [[-0.07701099]]
# 22800
# Forcing and Column integral:  [[-5.66975783]] -2.629858713944753
# TOA flux: [[-5.76696916]]
# Surf flux: [[0.09721133]]
# 22900
# Forcing and Column integral:  [[-5.71147103]] -0.11981422344843547
# TOA flux: [[-5.79381481]]
# Surf flux: [[0.08234378]]
# 23000
# Forcing and Column integral:  [[-5.75073973]] -0.7631910387674967
# TOA flux: [[-5.80232264]]
# Surf flux: [[0.05158291]]
# 23100
# Forcing and Column integral:  [[-5.70722655]] -5.410639335314433
# TOA flux: [[-5.76981216]]
# Surf flux: [[0.06258561]]
# 23200
# Forcing and Column integral:  [[-5.63113419]] -6.8578130491574605
# TOA flux: [[-5.63564672]]
# Surf flux: [[0.00451253]]
# 23300
# Forcing and Column integral:  [[-5.56633095]] -8.364250954786936
# TOA flux: [[-5.49379961]]
# Surf flux: [[-0.07253134]]
# 23400
# Forcing and Column integral:  [[-5.55568471]] -6.73289812485377
# TOA flux: [[-5.55265413]]
# Surf flux: [[-0.00303058]]
# 23500
# Forcing and Column integral:  [[-5.60174663]] -3.3976247851053873
# TOA flux: [[-5.64599583]]
# Surf flux: [[0.0442492]]
# 23600
# Forcing and Column integral:  [[-5.52337242]] -5.245352078278859
# TOA flux: [[-5.58020136]]
# Surf flux: [[0.05682893]]
# 23700
# Forcing and Column integral:  [[-5.52751405]] -8.726309239069622
# TOA flux: [[-5.41800522]]
# Surf flux: [[-0.10950883]]
# 23800
# Forcing and Column integral:  [[-5.52256383]] -5.193422067960103
# TOA flux: [[-5.55822354]]
# Surf flux: [[0.03565971]]
# 23900
# Forcing and Column integral:  [[-5.42380418]] -8.683095365365347
# TOA flux: [[-5.31893409]]
# Surf flux: [[-0.1048701]]
# 24000
# Forcing and Column integral:  [[-5.4443355]] -3.2354687293370565
# TOA flux: [[-5.48878128]]
# Surf flux: [[0.04444578]]
# 24100
# Forcing and Column integral:  [[-5.42991987]] -4.395215845108032
# TOA flux: [[-5.52125794]]
# Surf flux: [[0.09133808]]
# 24200
# Forcing and Column integral:  [[-5.29312153]] -4.296607587337494
# TOA flux: [[-5.40010813]]
# Surf flux: [[0.1069866]]
# 24300
# Forcing and Column integral:  [[-5.28962793]] -6.468565929730733
# TOA flux: [[-5.28745098]]
# Surf flux: [[-0.00217695]]
# 24400
# Forcing and Column integral:  [[-5.30155691]] 0.22002986749013265
# TOA flux: [[-5.38120051]]
# Surf flux: [[0.0796436]]
# 24500
# Forcing and Column integral:  [[-5.28095373]] -10.482122445901235
# TOA flux: [[-5.09396606]]
# Surf flux: [[-0.18698768]]
# 24600
# Forcing and Column integral:  [[-5.24299924]] -2.290002602736155
# TOA flux: [[-5.32440906]]
# Surf flux: [[0.08140981]]
# 24700
# Forcing and Column integral:  [[-5.09937789]] -6.167365946769714
# TOA flux: [[-5.1131621]]
# Surf flux: [[0.01378421]]
# 24800
# Forcing and Column integral:  [[-5.0793028]] -3.431716243426005
# TOA flux: [[-5.23423503]]
# Surf flux: [[0.15493223]]
# 24900
# Forcing and Column integral:  [[-5.18895644]] -3.0339742302894592
# TOA flux: [[-5.23349267]]
# Surf flux: [[0.04453623]]
# 25000
# Forcing and Column integral:  [[-5.03791306]] -6.083727547327677
# TOA flux: [[-5.06396623]]
# Surf flux: [[0.02605317]]
# 25100
# Forcing and Column integral:  [[-4.95709651]] -6.529235523541768
# TOA flux: [[-4.933285]]
# Surf flux: [[-0.02381151]]
# 25200
# Forcing and Column integral:  [[-4.98736885]] -6.65857722679774
# TOA flux: [[-4.93419008]]
# Surf flux: [[-0.05317877]]
# 25300
# Forcing and Column integral:  [[-5.04582278]] -6.071005879243215
# TOA flux: [[-5.06004591]]
# Surf flux: [[0.01422314]]
# 25400
# Forcing and Column integral:  [[-4.03057167]] 3.2392813428243
# TOA flux: [[-4.30483398]]
# Surf flux: [[0.27426231]]
# 25500
# Forcing and Column integral:  [[-2.61823203]] 1.7567039545377094
# TOA flux: [[-2.74055116]]
# Surf flux: [[0.12231913]]
# 25600
# Forcing and Column integral:  [[-2.76117704]] -2.524710148970286
# TOA flux: [[-2.78277108]]
# Surf flux: [[0.02159403]]
# 25700
# Forcing and Column integral:  [[-3.57700954]] -4.284657663504283
# TOA flux: [[-3.59993213]]
# Surf flux: [[0.02292259]]
# 25800
# Forcing and Column integral:  [[-3.89523819]] -7.78151230653127
# TOA flux: [[-3.81466678]]
# Surf flux: [[-0.08057141]]
# 25900
# Forcing and Column integral:  [[-3.97983746]] -4.363365551630656
# TOA flux: [[-3.97679967]]
# Surf flux: [[-0.00303779]]
# 26000
# Forcing and Column integral:  [[-3.58157078]] -2.5176431202888487
# TOA flux: [[-3.68757278]]
# Surf flux: [[0.10600201]]
# 26100
# Forcing and Column integral:  [[-3.54712226]] -1.9760703841845195
# TOA flux: [[-3.67383466]]
# Surf flux: [[0.12671239]]
# 26200
# Forcing and Column integral:  [[-3.60055342]] -3.4252579919497173
# TOA flux: [[-3.64324157]]
# Surf flux: [[0.04268815]]
# 26300
# Forcing and Column integral:  [[-3.47915059]] -4.157082308133443
# TOA flux: [[-3.50299751]]
# Surf flux: [[0.02384692]]
# 26400
# Forcing and Column integral:  [[-3.52052882]] -3.2714007918039956
# TOA flux: [[-3.55934467]]
# Surf flux: [[0.03881584]]
# 26500
# Forcing and Column integral:  [[-3.53798535]] -3.3208463923136393
# TOA flux: [[-3.5817131]]
# Surf flux: [[0.04372775]]
# 26600
# Forcing and Column integral:  [[-3.51523016]] -3.2516645073890684
# TOA flux: [[-3.56154931]]
# Surf flux: [[0.04631915]]
# 26700
# Forcing and Column integral:  [[-3.42507536]] -4.471039719581604
# TOA flux: [[-3.42802054]]
# Surf flux: [[0.00294518]]
# 26800
# Forcing and Column integral:  [[-3.41271173]] -6.640947456359863
# TOA flux: [[-3.31257288]]
# Surf flux: [[-0.10013884]]
# 26900
# Forcing and Column integral:  [[-3.35509651]] -9.602487847010295
# TOA flux: [[-3.15417696]]
# Surf flux: [[-0.20091954]]
# 27000
# Forcing and Column integral:  [[-3.37617929]] -5.265642880598704
# TOA flux: [[-3.33939896]]
# Surf flux: [[-0.03678032]]
# 27100
# Forcing and Column integral:  [[-3.45105022]] -9.680514307022095
# TOA flux: [[-3.25391547]]
# Surf flux: [[-0.19713475]]
# 27200
# Forcing and Column integral:  [[-3.22168424]] 1.3107410899798075
# TOA flux: [[-3.38556736]]
# Surf flux: [[0.16388312]]
# 27300
# Forcing and Column integral:  [[-3.2678051]] -3.4203240648905435
# TOA flux: [[-3.34979447]]
# Surf flux: [[0.08198937]]
# 27400
# Forcing and Column integral:  [[-3.35686952]] -7.221250040531158
# TOA flux: [[-3.2568102]]
# Surf flux: [[-0.10005932]]
# 27500
# Forcing and Column integral:  [[-3.19770982]] -1.5182734656333923
# TOA flux: [[-3.33440277]]
# Surf flux: [[0.13669295]]
# 27600
# Forcing and Column integral:  [[-3.24761674]] -4.305143622557322
# TOA flux: [[-3.24065133]]
# Surf flux: [[-0.00696541]]
# 27700
# Forcing and Column integral:  [[-3.29034882]] -6.350285893281301
# TOA flux: [[-3.22157257]]
# Surf flux: [[-0.06877624]]
# 27800
# Forcing and Column integral:  [[-3.23767041]] -2.309020759264628
# TOA flux: [[-3.32383219]]
# Surf flux: [[0.08616177]]
# 27900
# Forcing and Column integral:  [[-3.17740033]] -9.373155986467998
# TOA flux: [[-2.98417689]]
# Surf flux: [[-0.19322344]]
# 28000
# Forcing and Column integral:  [[-3.21895991]] -4.292809876600901
# TOA flux: [[-3.22108732]]
# Surf flux: [[0.00212741]]
# 28100
# Forcing and Column integral:  [[-3.18745286]] -3.873440797328949
# TOA flux: [[-3.205743]]
# Surf flux: [[0.01829014]]
# 28200
# Forcing and Column integral:  [[-3.23630447]] -3.835454435348511
# TOA flux: [[-3.26184232]]
# Surf flux: [[0.02553785]]
# 28300
# Forcing and Column integral:  [[-3.2851882]] -3.694107045332591
# TOA flux: [[-3.28884107]]
# Surf flux: [[0.00365287]]
# 28400
# Forcing and Column integral:  [[-3.20253854]] -6.254417248566946
# TOA flux: [[-3.14390965]]
# Surf flux: [[-0.05862889]]
# 28500
# Forcing and Column integral:  [[-3.27596112]] -3.0506997044881183
# TOA flux: [[-3.30838416]]
# Surf flux: [[0.03242304]]
# 28600
# Forcing and Column integral:  [[-3.18544746]] -6.353475013573965
# TOA flux: [[-3.08998352]]
# Surf flux: [[-0.09546394]]
# 28700
# Forcing and Column integral:  [[-3.16638863]] 2.228448147773743
# TOA flux: [[-3.22725263]]
# Surf flux: [[0.060864]]
# 28800
# Forcing and Column integral:  [[-3.1717406]] -0.09150366385777792
# TOA flux: [[-3.25208021]]
# Surf flux: [[0.08033961]]
# 28900
# Forcing and Column integral:  [[-3.07275722]] -3.6285650889078775
# TOA flux: [[-3.12759066]]
# Surf flux: [[0.05483345]]
# 29000
# Forcing and Column integral:  [[-3.07203517]] -3.2042826652526855
# TOA flux: [[-3.15705793]]
# Surf flux: [[0.08502277]]
# 29100
# Forcing and Column integral:  [[-2.98828769]] -4.046036349932352
# TOA flux: [[-2.99469456]]
# Surf flux: [[0.00640687]]
# 29200
# Forcing and Column integral:  [[-2.98389416]] -3.15337620973587
# TOA flux: [[-3.06374387]]
# Surf flux: [[0.07984971]]
# 29300
# Forcing and Column integral:  [[-3.13610902]] -0.07358903169631958
# TOA flux: [[-3.1993364]]
# Surf flux: [[0.06322739]]
# 29400
# Forcing and Column integral:  [[-2.97454568]] 0.06221758762995402
# TOA flux: [[-3.05720788]]
# Surf flux: [[0.0826622]]
# 29500
# Forcing and Column integral:  [[-3.05869944]] -2.8360346897443134
# TOA flux: [[-3.08957342]]
# Surf flux: [[0.03087398]]
# 29600
# Forcing and Column integral:  [[-2.91983605]] -6.7956540783246355
# TOA flux: [[-2.79609547]]
# Surf flux: [[-0.12374059]]
# 29700
# Forcing and Column integral:  [[-3.0151505]] -2.1089914854367575
# TOA flux: [[-3.09837453]]
# Surf flux: [[0.08322403]]
# 29800
# Forcing and Column integral:  [[-3.0403739]] -3.340849417845408
# TOA flux: [[-3.04212348]]
# Surf flux: [[0.00174958]]
# 29900
# Forcing and Column integral:  [[-2.95426652]] -6.770398507118225
# TOA flux: [[-2.82918807]]
# Surf flux: [[-0.12507845]]
# 30000
# Forcing and Column integral:  [[-2.93344796]] -3.6909449164072674
# TOA flux: [[-2.92067602]]
# Surf flux: [[-0.01277194]]
# 30100
# Forcing and Column integral:  [[-2.88455378]] -5.887669401963552
# TOA flux: [[-2.82859768]]
# Surf flux: [[-0.0559561]]
# 30200
# Forcing and Column integral:  [[-2.94920333]] -3.980790305137634
# TOA flux: [[-2.94772849]]
# Surf flux: [[-0.00147484]]
# 30300
# Forcing and Column integral:  [[-2.9047104]] -6.210193433761597
# TOA flux: [[-2.78668012]]
# Surf flux: [[-0.11803028]]
# 30400
# Forcing and Column integral:  [[-2.82313692]] -3.434228612581889
# TOA flux: [[-2.87569241]]
# Surf flux: [[0.05255549]]
# 30500
# Forcing and Column integral:  [[-2.89572588]] -2.8218356076876323
# TOA flux: [[-2.94024779]]
# Surf flux: [[0.04452191]]
# 30600
# Forcing and Column integral:  [[-2.90848766]] -2.7202463579177856
# TOA flux: [[-2.95033678]]
# Surf flux: [[0.04184912]]
# 30700
# Forcing and Column integral:  [[-2.89313612]] -5.893241972923279
# TOA flux: [[-2.82592092]]
# Surf flux: [[-0.0672152]]
# 30800
# Forcing and Column integral:  [[-2.85553278]] -5.987009043693543
# TOA flux: [[-2.77237864]]
# Surf flux: [[-0.08315414]]
# 30900
# Forcing and Column integral:  [[-2.86279901]] -3.869549934069316
# TOA flux: [[-2.86191102]]
# Surf flux: [[-0.00088799]]
# 31000
# Forcing and Column integral:  [[-2.83370589]] -5.9243456943829855
# TOA flux: [[-2.74281791]]
# Surf flux: [[-0.09088798]]
# 31100
# Forcing and Column integral:  [[-2.81197516]] -0.9482617910703023
# TOA flux: [[-2.81827138]]
# Surf flux: [[0.00629622]]
# 31200
# Forcing and Column integral:  [[-2.76764174]] -3.4041375557581586
# TOA flux: [[-2.79723924]]
# Surf flux: [[0.0295975]]
# 31300
# Forcing and Column integral:  [[-2.65968888]] -2.132133260567983
# TOA flux: [[-2.76951568]]
# Surf flux: [[0.1098268]]
# 31400
# Forcing and Column integral:  [[-2.7818251]] -3.0371076424916583
# TOA flux: [[-2.78917543]]
# Surf flux: [[0.00735033]]
# 31500
# Forcing and Column integral:  [[-2.8018223]] -2.6412440745035806
# TOA flux: [[-2.84056672]]
# Surf flux: [[0.03874442]]
# 31600
# Forcing and Column integral:  [[-2.75959149]] -7.870605464776357
# TOA flux: [[-2.61310571]]
# Surf flux: [[-0.14648577]]
# 31700
# Forcing and Column integral:  [[-2.66211128]] -0.9537265872955323
# TOA flux: [[-2.79309151]]
# Surf flux: [[0.13098023]]
# 31800
# Forcing and Column integral:  [[-2.61846727]] -5.986164951324463
# TOA flux: [[-2.50434212]]
# Surf flux: [[-0.11412515]]
# 31900
# Forcing and Column integral:  [[-2.6294657]] -3.2766951020558674
# TOA flux: [[-2.67610705]]
# Surf flux: [[0.04664136]]
# 32000
# Forcing and Column integral:  [[-2.70045765]] -1.807455358505249
# TOA flux: [[-2.77672227]]
# Surf flux: [[0.07626462]]
# 32100
# Forcing and Column integral:  [[-2.67736911]] 2.631328298250834
# TOA flux: [[-2.73581235]]
# Surf flux: [[0.05844324]]
# 32200
# Forcing and Column integral:  [[-2.60286106]] -5.5444480895996096
# TOA flux: [[-2.54868125]]
# Surf flux: [[-0.05417981]]
# 32300
# Forcing and Column integral:  [[-2.68662728]] 0.41118478775024414
# TOA flux: [[-2.75214687]]
# Surf flux: [[0.06551959]]
# 32400
# Forcing and Column integral:  [[-2.62982296]] 3.4480143133799235
# TOA flux: [[-2.73936778]]
# Surf flux: [[0.10954481]]
# 32500
# Forcing and Column integral:  [[-2.50132832]] -2.2420263266563416
# TOA flux: [[-2.60223309]]
# Surf flux: [[0.10090477]]
# 32600
# Forcing and Column integral:  [[-2.61500755]] -5.7308665744463605
# TOA flux: [[-2.53046249]]
# Surf flux: [[-0.08454506]]
# 32700
# Forcing and Column integral:  [[-2.58342794]] -3.225721342563629
# TOA flux: [[-2.61545668]]
# Surf flux: [[0.03202874]]
# 32800
# Forcing and Column integral:  [[-2.5298129]] 0.43222486893335976
# TOA flux: [[-2.61360802]]
# Surf flux: [[0.08379512]]
# 32900
# Forcing and Column integral:  [[-2.59836512]] -1.705516795317332
# TOA flux: [[-2.6751499]]
# Surf flux: [[0.07678478]]
# 33000
# Forcing and Column integral:  [[-2.51046063]] -5.528962905406952
# TOA flux: [[-2.45518352]]
# Surf flux: [[-0.05527711]]
# 33100
# Forcing and Column integral:  [[-2.53753634]] -2.507194170951843
# TOA flux: [[-2.58128252]]
# Surf flux: [[0.04374618]]
# 33200
# Forcing and Column integral:  [[-2.44780792]] 3.618999125957489
# TOA flux: [[-2.55846519]]
# Surf flux: [[0.11065727]]
# 33300
# Forcing and Column integral:  [[-2.49132767]] -5.43975598971049
# TOA flux: [[-2.43834371]]
# Surf flux: [[-0.05298396]]
# 33400
# Forcing and Column integral:  [[-2.48679887]] -3.1231675521532694
# TOA flux: [[-2.51962772]]
# Surf flux: [[0.03282886]]
# 33500
# Forcing and Column integral:  [[-2.45148207]] -5.4381546552975975
# TOA flux: [[-2.39848957]]
# Surf flux: [[-0.05299251]]
# 33600
# Forcing and Column integral:  [[-2.48545469]] -5.663120210965475
# TOA flux: [[-2.37155749]]
# Surf flux: [[-0.1138972]]
# 33700
# Forcing and Column integral:  [[-2.38429445]] -5.358761722246806
# TOA flux: [[-2.33331288]]
# Surf flux: [[-0.05098157]]
# 33800
# Forcing and Column integral:  [[-2.37639106]] -0.6843481548627217
# TOA flux: [[-2.50225563]]
# Surf flux: [[0.12586457]]
# 33900
# Forcing and Column integral:  [[-2.37325948]] -3.3771187035242716
# TOA flux: [[-2.39093502]]
# Surf flux: [[0.01767555]]
# 34000
# Forcing and Column integral:  [[-2.38782961]] -2.2765814606348673
# TOA flux: [[-2.43651483]]
# Surf flux: [[0.04868522]]
# 34100
# Forcing and Column integral:  [[-2.41037134]] -1.5562349875768027
# TOA flux: [[-2.48909352]]
# Surf flux: [[0.07872218]]
# 34200
# Forcing and Column integral:  [[-2.28151941]] -0.6007767717043558
# TOA flux: [[-2.40746474]]
# Surf flux: [[0.12594533]]
# 34300
# Forcing and Column integral:  [[-2.42779878]] -0.22436742703119913
# TOA flux: [[-2.46175474]]
# Surf flux: [[0.03395596]]
# 34400
# Forcing and Column integral:  [[-2.3508133]] -5.493077694574992
# TOA flux: [[-2.24041523]]
# Surf flux: [[-0.11039806]]
# 34500
# Forcing and Column integral:  [[-2.33335696]] -7.115811200936635
# TOA flux: [[-2.18739294]]
# Surf flux: [[-0.14596402]]
# 34600
# Forcing and Column integral:  [[-2.29791668]] -7.033980929056804
# TOA flux: [[-2.15587607]]
# Surf flux: [[-0.14204061]]
# 34700
# Forcing and Column integral:  [[-2.36967485]] -0.11160728375116984
# TOA flux: [[-2.41004663]]
# Surf flux: [[0.04037178]]
# 34800
# Forcing and Column integral:  [[-2.32129059]] 1.1434498023986817
# TOA flux: [[-2.42246426]]
# Surf flux: [[0.10117368]]
# 34900
# Forcing and Column integral:  [[-2.35178749]] -3.3681074444452923
# TOA flux: [[-2.35780432]]
# Surf flux: [[0.00601684]]
# 35000
# Forcing and Column integral:  [[-2.32972923]] -7.042987531820933
# TOA flux: [[-2.18847315]]
# Surf flux: [[-0.14125609]]
# 35100
# Forcing and Column integral:  [[-2.32686772]] -2.749441564877828
# TOA flux: [[-2.34241093]]
# Surf flux: [[0.0155432]]
# 35200
# Forcing and Column integral:  [[-2.26949721]] -2.89141783952713
# TOA flux: [[-2.29014919]]
# Surf flux: [[0.02065198]]
# 35300
# Forcing and Column integral:  [[-2.3364146]] 2.916499388217926
# TOA flux: [[-2.40485923]]
# Surf flux: [[0.06844463]]
# 35400
# Forcing and Column integral:  [[-2.32960746]] -3.3965475686391193
# TOA flux: [[-2.33739056]]
# Surf flux: [[0.00778309]]
# 35500
# Forcing and Column integral:  [[-2.26473936]] -2.820198170344035
# TOA flux: [[-2.31101634]]
# Surf flux: [[0.04627698]]
# 35600
# Forcing and Column integral:  [[-2.18685122]] -2.358551958401998
# TOA flux: [[-2.25792478]]
# Surf flux: [[0.07107356]]
# 35700
# Forcing and Column integral:  [[-2.22835968]] -3.2794837832450865
# TOA flux: [[-2.2419129]]
# Surf flux: [[0.01355322]]
# 35800
# Forcing and Column integral:  [[-2.15501836]] -1.2826831253369648
# TOA flux: [[-2.23746037]]
# Surf flux: [[0.082442]]
# 35900
# Forcing and Column integral:  [[-2.21615565]] -0.04168240944544474
# TOA flux: [[-2.25439539]]
# Surf flux: [[0.03823974]]
# 36000
# Forcing and Column integral:  [[-2.12711873]] 1.6192139681180318
# TOA flux: [[-2.24826952]]
# Surf flux: [[0.12115079]]
# 36100
# Forcing and Column integral:  [[-2.13848751]] 3.633861661752065
# TOA flux: [[-2.23816234]]
# Surf flux: [[0.09967483]]
# 36200
# Forcing and Column integral:  [[-2.18218025]] -2.6079178055127463
# TOA flux: [[-2.19595292]]
# Surf flux: [[0.01377267]]
# 36300
# Forcing and Column integral:  [[-2.1081566]] -7.270670987764994
# TOA flux: [[-1.94001912]]
# Surf flux: [[-0.16813748]]
# 36400
# Forcing and Column integral:  [[-2.10668005]] -3.1618743642171223
# TOA flux: [[-2.11248196]]
# Surf flux: [[0.00580191]]
# 36500
# Forcing and Column integral:  [[-2.16783321]] -0.3530622696876526
# TOA flux: [[-2.17667362]]
# Surf flux: [[0.0088404]]
# 36600
# Forcing and Column integral:  [[-2.06221254]] 1.4405921292304993
# TOA flux: [[-2.16571778]]
# Surf flux: [[0.10350524]]
# 36700
# Forcing and Column integral:  [[-2.18369268]] -2.6038335164388022
# TOA flux: [[-2.19640072]]
# Surf flux: [[0.01270804]]
# 36800
# Forcing and Column integral:  [[-2.14623443]] -2.117533369064331
# TOA flux: [[-2.18287438]]
# Surf flux: [[0.03663995]]
# 36900
# Forcing and Column integral:  [[-2.08118139]] -2.6492636624972024
# TOA flux: [[-2.12776498]]
# Surf flux: [[0.04658359]]
# 37000
# Forcing and Column integral:  [[-2.04913587]] 1.4660032439231871
# TOA flux: [[-2.14930939]]
# Surf flux: [[0.10017352]]
# 37100
# Forcing and Column integral:  [[-1.94836739]] -5.03831303358078
# TOA flux: [[-1.87110018]]
# Surf flux: [[-0.0772672]]
# 37200
# Forcing and Column integral:  [[-2.0597709]] 0.8861286282539368
# TOA flux: [[-2.13362574]]
# Surf flux: [[0.07385484]]
# 37300
# Forcing and Column integral:  [[-2.06910599]] -2.0490526072184245
# TOA flux: [[-2.10407953]]
# Surf flux: [[0.03497354]]
# 37400
# Forcing and Column integral:  [[-2.0386964]] -4.995703464349111
# TOA flux: [[-1.99122375]]
# Surf flux: [[-0.04747264]]
# 37500
# Forcing and Column integral:  [[-1.97873531]] 3.770659913221995
# TOA flux: [[-2.07857885]]
# Surf flux: [[0.09984354]]
# 37600
# Forcing and Column integral:  [[-2.04220545]] 0.16786991914113364
# TOA flux: [[-2.07551706]]
# Surf flux: [[0.0333116]]
# 37700
# Forcing and Column integral:  [[-1.97613452]] -2.539663880666097
# TOA flux: [[-2.02139708]]
# Surf flux: [[0.04526256]]
# 37800
# Forcing and Column integral:  [[-2.0833294]] -2.4859500122070313
# TOA flux: [[-2.08701622]]
# Surf flux: [[0.00368682]]
# 37900
# Forcing and Column integral:  [[-1.99151856]] -7.161602110862732
# TOA flux: [[-1.82811691]]
# Surf flux: [[-0.16340165]]
# 38000
# Forcing and Column integral:  [[-1.97996425]] -2.5970808124542235
# TOA flux: [[-1.99623279]]
# Surf flux: [[0.01626854]]
# 38100
# Forcing and Column integral:  [[-1.96771107]] -7.153307805856069
# TOA flux: [[-1.80558541]]
# Surf flux: [[-0.16212565]]
# 38200
# Forcing and Column integral:  [[-1.94267596]] -4.923418424129486
# TOA flux: [[-1.89319375]]
# Surf flux: [[-0.04948222]]
# 38300
# Forcing and Column integral:  [[-1.93537127]] -2.2116517917315166
# TOA flux: [[-1.95962424]]
# Surf flux: [[0.02425297]]
# 38400
# ...
# TOA flux: [[-0.80622328]]
# Surf flux: [[0.0289573]]
# 54600
# Forcing and Column integral:  [[-0.82093082]] -5.689375514984131
# TOA flux: [[-0.67274695]]
# Surf flux: [[-0.14818387]]
# 54700
# Forcing and Column integral:  [[-0.80401566]] -5.600832989215851
# TOA flux: [[-0.65719765]]
# Surf flux: [[-0.14681801]]
# 54800
# Forcing and Column integral:  [[-0.78392081]] -3.7333456405003864
# TOA flux: [[-0.71514478]]
# Surf flux: [[-0.06877603]]
# 54900
# Forcing and Column integral:  [[-0.72716676]] -5.412779161135355
# TOA flux: [[-0.57917935]]
# Surf flux: [[-0.14798741]]
# 55000
# Forcing and Column integral:  [[-0.68198471]] -3.808442118167877
# TOA flux: [[-0.61171225]]
# Surf flux: [[-0.07027245]]
# 55100
# Forcing and Column integral:  [[-0.92086292]] -2.8269290335973105
# TOA flux: [[-0.91148359]]
# Surf flux: [[-0.00937932]]
# 55200
# Forcing and Column integral:  [[-0.83668335]] -3.969210913181305
# TOA flux: [[-0.76679744]]
# Surf flux: [[-0.06988591]]
# 55300
# Forcing and Column integral:  [[-0.97539457]] -1.297872170607249
# TOA flux: [[-0.97508991]]
# Surf flux: [[-0.00030466]]
# 55400
# Forcing and Column integral:  [[-0.87939889]] -3.828976340293884
# TOA flux: [[-0.80641005]]
# Surf flux: [[-0.07298884]]
# 55500
# Forcing and Column integral:  [[-0.84144382]] -3.786271487871806
# TOA flux: [[-0.77511201]]
# Surf flux: [[-0.0663318]]
# 55600
# Forcing and Column integral:  [[-0.86980965]] -3.791169255574544
# TOA flux: [[-0.80409404]]
# Surf flux: [[-0.06571561]]
# 55700
# Forcing and Column integral:  [[-0.88461283]] 2.0490402015050253
# TOA flux: [[-0.94737979]]
# Surf flux: [[0.06276696]]
# 55800
# Forcing and Column integral:  [[-0.97308837]] 1.7788514924049377
# TOA flux: [[-1.0244329]]
# Surf flux: [[0.05134454]]
# 55900
# Forcing and Column integral:  [[-0.9477144]] 1.3630255818367005
# TOA flux: [[-0.98640963]]
# Surf flux: [[0.03869523]]
# 56000
# Forcing and Column integral:  [[-0.87106107]] -0.3494411277770996
# TOA flux: [[-0.91591929]]
# Surf flux: [[0.04485822]]
# 56100
# Forcing and Column integral:  [[-0.94924435]] 1.467684218088786
# TOA flux: [[-0.99114992]]
# Surf flux: [[0.04190557]]
# 56200
# Forcing and Column integral:  [[-0.91460669]] -0.037549173831939696
# TOA flux: [[-0.98382378]]
# Surf flux: [[0.06921709]]
# 56300
# Forcing and Column integral:  [[-0.95255619]] 1.7618353859583538
# TOA flux: [[-1.0121585]]
# Surf flux: [[0.05960231]]
# 56400
# Forcing and Column integral:  [[-0.8947182]] -0.3763676754633586
# TOA flux: [[-0.94056003]]
# Surf flux: [[0.04584183]]
# 56500
# Forcing and Column integral:  [[-0.96149573]] 1.7884728590647379
# TOA flux: [[-1.02225953]]
# Surf flux: [[0.06076379]]
# 56600
# Forcing and Column integral:  [[-0.94446657]] -0.42470098654429117
# TOA flux: [[-0.98477278]]
# Surf flux: [[0.04030621]]
# 56700
# Forcing and Column integral:  [[-0.93951375]] 3.9604659112294516
# TOA flux: [[-0.99314839]]
# Surf flux: [[0.05363465]]
# 56800
# Forcing and Column integral:  [[-0.87444302]] -0.04569531043370565
# TOA flux: [[-0.93840306]]
# Surf flux: [[0.06396004]]
# 56900
# Forcing and Column integral:  [[-0.77113766]] -4.365388527711232
# TOA flux: [[-0.63400763]]
# Surf flux: [[-0.13713003]]
# 57000
# Forcing and Column integral:  [[0.74431092]] -0.509604385693868
# TOA flux: [[0.79327172]]
# Surf flux: [[-0.0489608]]
# 57100
# Forcing and Column integral:  [[0.20229897]] 0.5015462279319763
# TOA flux: [[0.19103902]]
# Surf flux: [[0.01125995]]
# 57200
# Forcing and Column integral:  [[-0.31897542]] 0.9325567626953125
# TOA flux: [[-0.37362489]]
# Surf flux: [[0.05464947]]
# 57300
# Forcing and Column integral:  [[-0.21914484]] 0.6135318048795064
# TOA flux: [[-0.27124017]]
# Surf flux: [[0.05209532]]
# 57400
# Forcing and Column integral:  [[-0.12971178]] 0.679239342212677
# TOA flux: [[-0.18062619]]
# Surf flux: [[0.05091441]]
# 57500
# Forcing and Column integral:  [[-0.07008989]] 1.2726340516408285
# TOA flux: [[-0.13094421]]
# Surf flux: [[0.06085433]]
# 57600
# Forcing and Column integral:  [[-0.20545326]] 2.1744281697273253
# TOA flux: [[-0.23701673]]
# Surf flux: [[0.03156347]]
# 57700
# Forcing and Column integral:  [[-0.13911879]] 4.800260501702627
# TOA flux: [[-0.1864481]]
# Surf flux: [[0.04732931]]
# 57800
# Forcing and Column integral:  [[-0.17859861]] 2.1677109885215757
# TOA flux: [[-0.21350576]]
# Surf flux: [[0.03490714]]
# 57900
# Forcing and Column integral:  [[-0.08285711]] 0.33916709979375204
# TOA flux: [[-0.11799255]]
# Surf flux: [[0.03513544]]
# 58000
# Forcing and Column integral:  [[-0.04086852]] 0.14623836119969685
# TOA flux: [[-0.0901292]]
# Surf flux: [[0.04926068]]
# 58100
# Forcing and Column integral:  [[-0.1176369]] 0.3154240036010742
# TOA flux: [[-0.15187177]]
# Surf flux: [[0.03423488]]
# 58200
# Forcing and Column integral:  [[-0.15238755]] 2.582021443049113
# TOA flux: [[-0.20010787]]
# Surf flux: [[0.04772032]]
# 58300
# Forcing and Column integral:  [[-0.11799316]] 0.24170588493347167
# TOA flux: [[-0.15029903]]
# Surf flux: [[0.03230587]]
# 58400
# Forcing and Column integral:  [[-0.09305311]] 0.43991953690846763
# TOA flux: [[-0.12743002]]
# Surf flux: [[0.03437691]]
# 58500
# Forcing and Column integral:  [[-0.13454676]] 4.808991700013479
# TOA flux: [[-0.18118613]]
# Surf flux: [[0.04663937]]
# 58600
# Forcing and Column integral:  [[-0.1933663]] 2.56285142660141
# TOA flux: [[-0.24168922]]
# Surf flux: [[0.04832292]]
# 58700
# Forcing and Column integral:  [[-0.15657521]] 2.1995348755518593
# TOA flux: [[-0.19142231]]
# Surf flux: [[0.0348471]]
# 58800
# Forcing and Column integral:  [[-0.14441549]] 4.812557020187378
# TOA flux: [[-0.19305492]]
# Surf flux: [[0.04863944]]
# 58900
# Forcing and Column integral:  [[-0.1008738]] 2.305131246248881
# TOA flux: [[-0.13634497]]
# Surf flux: [[0.03547117]]
# 59000
# Forcing and Column integral:  [[-0.14390354]] 4.796955909729004
# TOA flux: [[-0.18780962]]
# Surf flux: [[0.04390608]]
# 59100
# Forcing and Column integral:  [[-0.10823176]] 0.7484035476048787
# TOA flux: [[-0.1545548]]
# Surf flux: [[0.04632304]]
# 59200
# Forcing and Column integral:  [[-0.11652957]] 2.6207986958821614
# TOA flux: [[-0.16414447]]
# Surf flux: [[0.0476149]]
# 59300
# Forcing and Column integral:  [[-0.17480195]] 2.198654860655467
# TOA flux: [[-0.21228481]]
# Surf flux: [[0.03748286]]
# 59400
# Forcing and Column integral:  [[-0.13090544]] 2.628146895567576
# TOA flux: [[-0.17873504]]
# Surf flux: [[0.0478296]]
# 59500
# Forcing and Column integral:  [[-0.06181083]] 3.1351148557662962
# TOA flux: [[-0.12780288]]
# Surf flux: [[0.06599205]]
# 59600
# Forcing and Column integral:  [[-0.0493619]] 0.6924846092859904
# TOA flux: [[-0.09749844]]
# Surf flux: [[0.04813654]]
# 59700
# Forcing and Column integral:  [[-0.13678726]] 4.822591509024302
# TOA flux: [[-0.1861731]]
# Surf flux: [[0.04938584]]
# 59800
# Forcing and Column integral:  [[-0.10626784]] 3.0746216305096943
# TOA flux: [[-0.16946786]]
# Surf flux: [[0.06320002]]
# 59900
# Forcing and Column integral:  [[-0.08447465]] 3.0998257247606915
# TOA flux: [[-0.14895147]]
# Surf flux: [[0.06447683]]
# 60000
# Forcing and Column integral:  [[-0.08912726]] 4.879904001553854
# TOA flux: [[-0.13707925]]
# Surf flux: [[0.04795199]]
# 60100
# Forcing and Column integral:  [[-0.08003258]] 0.1341349720954895
# TOA flux: [[-0.12508725]]
# Surf flux: [[0.04505466]]
# 60200
# Forcing and Column integral:  [[-0.11847703]] 0.46889851172765096
# TOA flux: [[-0.15327367]]
# Surf flux: [[0.03479664]]
# 60300
# Forcing and Column integral:  [[-0.14597209]] 0.3581730278333028
# TOA flux: [[-0.1806794]]
# Surf flux: [[0.03470732]]
# 60400
# Forcing and Column integral:  [[-0.14455263]] 2.142746041615804
# TOA flux: [[-0.17877174]]
# Surf flux: [[0.03421911]]
# 60500
# Forcing and Column integral:  [[-0.10509396]] 2.2437396597862245
# TOA flux: [[-0.14031941]]
# Surf flux: [[0.03522545]]
# 60600
# Forcing and Column integral:  [[-0.15877947]] 2.144516218503316
# TOA flux: [[-0.19120136]]
# Surf flux: [[0.03242189]]
# 60700
# Forcing and Column integral:  [[-0.16183395]] 2.252631275653839
# TOA flux: [[-0.19591716]]
# Surf flux: [[0.03408321]]
# 60800
# Forcing and Column integral:  [[-0.18180703]] 0.6122326151529948
# TOA flux: [[-0.22964169]]
# Surf flux: [[0.04783466]]
# 60900
# Forcing and Column integral:  [[-0.07952482]] -4.400097920099895
# TOA flux: [[0.02459201]]
# Surf flux: [[-0.10411683]]
# 61000
# Forcing and Column integral:  [[-0.05875013]] -2.8164324680964152
# TOA flux: [[-0.02249071]]
# Surf flux: [[-0.03625942]]
# 61100
# Forcing and Column integral:  [[-0.07015058]] -1.544198751449585
# TOA flux: [[-0.0779456]]
# Surf flux: [[0.00779502]]
# 61200
# Forcing and Column integral:  [[-0.0322827]] -1.5141368762652079
# TOA flux: [[-0.01533426]]
# Surf flux: [[-0.01694844]]
# 61300
# Forcing and Column integral:  [[-0.08956389]] -1.5901908206939697
# TOA flux: [[-0.08664188]]
# Surf flux: [[-0.002922]]
# 61400
# Forcing and Column integral:  [[-0.05172449]] -2.8382341559727986
# TOA flux: [[0.00024974]]
# Surf flux: [[-0.05197423]]
# 61500
# Forcing and Column integral:  [[-0.09850272]] -1.1183771626154582
# TOA flux: [[-0.09190284]]
# Surf flux: [[-0.00659988]]
# 61600
# Forcing and Column integral:  [[0.03621103]] -2.733297609488169
# TOA flux: [[0.10562941]]
# Surf flux: [[-0.06941839]]
# 61700
# Forcing and Column integral:  [[0.00292415]] -2.757815333207448
# TOA flux: [[0.07448914]]
# Surf flux: [[-0.071565]]
# 61800
# Forcing and Column integral:  [[-0.16656293]] -1.7106291635831197
# TOA flux: [[-0.12859051]]
# Surf flux: [[-0.03797242]]
# 61900
# Forcing and Column integral:  [[-0.16479596]] -1.7120525844891865
# TOA flux: [[-0.17086141]]
# Surf flux: [[0.00606545]]
# 62000
# Forcing and Column integral:  [[-0.0492155]] -4.4050934187571205
# TOA flux: [[0.06076353]]
# Surf flux: [[-0.10997903]]
# 62100
# Forcing and Column integral:  [[-0.09444023]] -2.90214826742808
# TOA flux: [[-0.0435814]]
# Surf flux: [[-0.05085883]]
# 62200
# Forcing and Column integral:  [[-0.0285979]] -4.362556571960449
# TOA flux: [[0.07387026]]
# Surf flux: [[-0.10246815]]
# 62300
# Forcing and Column integral:  [[-0.04012869]] -4.345237889289856
# TOA flux: [[0.0610898]]
# Surf flux: [[-0.10121849]]
# 62400
# Forcing and Column integral:  [[-0.15967061]] 3.0467069061597187
# TOA flux: [[-0.22469685]]
# Surf flux: [[0.06502624]]
# 62500
# Forcing and Column integral:  [[-0.12215396]] 0.7712706979115804
# TOA flux: [[-0.16865227]]
# Surf flux: [[0.04649832]]
# 62600
# Forcing and Column integral:  [[-0.19166327]] 2.169502085049947
# TOA flux: [[-0.22395731]]
# Surf flux: [[0.03229404]]
# 62700
# Forcing and Column integral:  [[-0.06310723]] 0.8352384312947592
# TOA flux: [[-0.11176748]]
# Surf flux: [[0.04866025]]
# 62800
# Forcing and Column integral:  [[-0.04104541]] 0.7645123100280762
# TOA flux: [[-0.08865241]]
# Surf flux: [[0.04760701]]
# 62900
# Forcing and Column integral:  [[-0.01553412]] 1.3798817420005798
# TOA flux: [[-0.0830148]]
# Surf flux: [[0.06748068]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-518e51fa0b73> in <module>()
#     109 for i in range(100000):
#     110
# --> 111     diagnostics, new_state = simple_physics(state, timestep)
#     112     state.update(diagnostics)
#     113     state.update(new_state)
#
# ~/anaconda3/lib/python3.6/site-packages/sympl/_core/base_components.py in __call__(self, state, timestep)
#     611         self._check_self_is_initialized()
#     612         self._input_checker.check_inputs(state)
# --> 613         raw_state = get_numpy_arrays_with_properties(state, self.input_properties)
#     614         if self.uses_tracers:
#     615             raw_state['tracers'] = self._tracer_packer.pack(state)
#
# ~/anaconda3/lib/python3.6/site-packages/sympl/_core/get_np_arrays.py in get_numpy_arrays_with_properties(state, property_dictionary)
#      12         ensure_quantity_has_units(state[name], name)
#      13         try:
# ---> 14             quantity = state[name].to_units(properties['units'])
#      15         except ValueError:
#      16             raise InvalidStateError(
#
# ~/anaconda3/lib/python3.6/site-packages/sympl/_core/dataarray.py in to_units(self, units)
#      48             raise KeyError('"units" not present in attrs')
#      49         try:
# ---> 50             return to_units_function(self, units)
#      51         except DimensionalityError as err:
#      52             raise ValueError(str(err))
#
# ~/anaconda3/lib/python3.6/site-packages/sympl/_core/units.py in data_array_to_units(value, units)
#      79         raise TypeError(
#      80             'Cannot retrieve units from type {}'.format(type(value)))
# ---> 81     elif unit_registry(value.attrs['units']) != unit_registry(units):
#      82         attrs = value.attrs.copy()
#      83         value = unit_registry.Quantity(value, value.attrs['units']).to(units).magnitude
#
# ~/anaconda3/lib/python3.6/site-packages/sympl/_core/units.py in __call__(self, input_string, **kwargs)
#      11                 u'°', 'degree'
#      12             ),
# ---> 13             **kwargs)
#      14
#      15
#
# ~/anaconda3/lib/python3.6/site-packages/pint/registry.py in parse_expression(self, input_string, case_sensitive, **values)
#     863         gen = tokenizer(input_string)
#     864
# --> 865         return build_eval_tree(gen).evaluate(lambda x: self._eval_token(x,
#     866                                                                         case_sensitive=case_sensitive,
#     867                                                                         **values))
#
# ~/anaconda3/lib/python3.6/site-packages/pint/pint_eval.py in evaluate(self, define_op, bin_op, un_op)
#      83                 raise DefinitionSyntaxError('missing binary operator "%s"' % op_text)
#      84             left = self.left.evaluate(define_op, bin_op, un_op)
# ---> 85             return bin_op[op_text](left, self.right.evaluate(define_op, bin_op, un_op))
#      86         elif self.operator:
#      87             # unary operator
#
# ~/anaconda3/lib/python3.6/site-packages/pint/pint_eval.py in evaluate(self, define_op, bin_op, un_op)
#      92         else:
#      93             # single value
# ---> 94             return define_op(self.left)
#      95
#      96
#
# ~/anaconda3/lib/python3.6/site-packages/pint/registry.py in <lambda>(x)
#     865         return build_eval_tree(gen).evaluate(lambda x: self._eval_token(x,
#     866                                                                         case_sensitive=case_sensitive,
# --> 867                                                                         **values))
#     868
#     869     __call__ = parse_expression
#
# ~/anaconda3/lib/python3.6/site-packages/pint/registry.py in _eval_token(self, token, case_sensitive, **values)
#     844             else:
#     845                 return self.Quantity(1, UnitsContainer({self.get_name(token_text,
# --> 846                                                                       case_sensitive=case_sensitive) : 1}))
#     847         elif token_type == NUMBER:
#     848             return ParserHelper.eval_token(token)
#
# ~/anaconda3/lib/python3.6/site-packages/pint/registry.py in get_name(self, name_or_alias, case_sensitive)
#     486         if prefix:
#     487             name = prefix + unit_name
# --> 488             symbol = self.get_symbol(name)
#     489             prefix_def = self._prefixes[prefix]
#     490             self._units[name] = UnitDefinition(name, symbol, (), prefix_def.converter,
#
# ~/anaconda3/lib/python3.6/site-packages/pint/registry.py in get_symbol(self, name_or_alias)
#     497         """Return the preferred alias for a unit
#     498         """
# --> 499         candidates = self._dedup_candidates(self.parse_unit_name(name_or_alias))
#     500         if not candidates:
#     501             raise UndefinedUnitError(name_or_alias)
#
# ~/anaconda3/lib/python3.6/site-packages/pint/registry.py in _dedup_candidates(self, candidates)
#     448             e.g. ('kilo', 'gram', '') and ('', 'kilogram', '')
#     449         """
# --> 450         candidates = tuple(candidates)
#     451         if len(candidates) < 2:
#     452             return candidates
#
# ~/anaconda3/lib/python3.6/site-packages/pint/registry.py in parse_unit_name(self, unit_name, case_sensitive)
#     760         edw = unit_name.endswith
#     761         for suffix, prefix in itertools.product(self._suffixes, self._prefixes):
# --> 762             if stw(prefix) and edw(suffix):
#     763                 name = unit_name[len(prefix):]
#     764                 if suffix:
#
# KeyboardInterrupt:
